# %%
from src.light2night_pipeline import relight_content_image

relight_content_image(
    content_path="data/compressed/bottle_sun.tiff",
    style_path="data/compressed/bottle_cloudy.tiff",
    isd_model="unet", # mock, vit, unet
    output_path="data/target.png",
    shading_only=True,
    compression_factor=0.5
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.light2night_pipeline import relight_content_image
# ----> 3 relight_content_image(
#       4     content_path="data/compressed/bottle_sun.tiff",
#       5     style_path="data/compressed/bottle_cloudy.tiff",
#       6     isd_model="unet", # mock, vit, unet
#       7     output_path="data/target.png",
#       8     shading_only=True,
#       9     compression_factor=0.5
#      10 )
#
# File ~\CLASS DOCS\Perception\FINAL PROJECT\src\light2night_pipeline.py:62, in relight_content_image(content_path, style_path, isd_model, output_path, shading_only, compression_factor)
#      60 # --- 2. Estimate ISD map for content ---
#      61 img_tensor = torch.from_numpy(content_img).permute(2, 0, 1).unsqueeze(0).to(device)
# ---> 62 isd_map = model(img_tensor)
#      63 isd_norm = torch.norm(isd_map, dim=1, keepdim=True)
#      64 isd_map = torch.where(isd_norm != 0, isd_map / isd_norm, isd_map)
#
# File ~\anaconda3\envs\py-3.12\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\py-3.12\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\CLASS DOCS\Perception\FINAL PROJECT\src\models.py:155, in ResNet50UNet.forward(self, x)
#     153 self.logger.debug(f"{self.__class__.__name__} bottlneck shape = {x4.shape}")
#     154 # Decoder with skip connections
# --> 155 d4 = self.up4(x4, x3)  # skip enc layer4
#     156 d3 = self.up3(d4, x2)  # skip enc layer2`
#     157 d2 = self.up2(d3, x1)  # skip enc layer1
#
# File ~\anaconda3\envs\py-3.12\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\py-3.12\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\CLASS DOCS\Perception\FINAL PROJECT\src\models.py:72, in UpBlock.forward(self, x, skip)
#      70 x = self.up(x)
#      71 if skip is not None:
# ---> 72     x = torch.cat([x, skip], dim=1)
#      73 x = self.conv(x)
#      74 if self.se_block:
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 190 but got size 189 for tensor number 1 in the list.
